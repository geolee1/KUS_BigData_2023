# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# ...

# %% [markdown]
# # 데이터의 운영(Pandas)

# %% [markdown]
# ## 시리즈(Series)

# %% [markdown]
# ### 시리즈의 생성 : 리스트

# %%
import pandas as pd
# 리스트로 Series 생성
list_data = ['Dog', 'Cat', 'Tiger', 'Lion', 'Monkey']
sd1 = pd.Series(list_data, index=['0', '1', '2', '3', '4'])
# 데이터 확인
sd1
# Out:
# 0       Dog
# 1       Cat
# 2     Tiger
# 3      Lion
# 4    Monkey
# dtype: object

# %% [markdown]
# ### 시리즈의 생성 : 딕셔너리

# %%
import pandas as pd
# 딕셔너리로 Series 생성
dict_data = {'a':1, 'b':2, 'c':3}
sd2 = pd.Series(dict_data)
# 데이터 확인
sd2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ### 시리즈의 생성 : 튜플

# %%
import pandas as pd
# 튜플로 Series 생성
tup_data = ('이순신', '1991-03-15', '남')
sd3 = pd.Series(tup_data, index=['이름', '생년월일', '성별'])
# 데이터 확인
sd3
# Out:
# 이름             이순신
# 생년월일    1991-03-15
# 성별               남
# dtype: object

# %% [markdown]
# ## 데이터프레임(DataFrame)

# %% [markdown]
# ### 데이터프레임의 생성 : 리스트

# %%
# 라이브러리 불러오기
import pandas as pd

# 리스트로 데이터프레임 생성 - 중첩된 리스트 사용
df1 = pd.DataFrame([['Dog', '7'], ['Cat', '9'], ['Tiger', '2'], ['Lion', '3'], ['Monkey', '1']],
                   index=['0', '1', '2', '3', '4'], 
                   columns=['동물', '나이'])

# 타입 확인
print(type(df1))
# 데이터 확인
print(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        동물 나이
# 0     Dog  7
# 1     Cat  9
# 2   Tiger  2
# 3    Lion  3
# 4  Monkey  1

# %% [markdown]
# ### 데이터프레임의 생성 : 딕셔너리

# %%
# 라이브러리 불러오기
import pandas as pd

# 딕셔너리로 데이터프레임 생성 - 딕셔너리안의 리시트
dict_data = {'동물':['Dog', 'Cat', 'Tiger', 'Lion', 'Monkey'],'나이':[7, 9, 2, 3 ,1]}
df2 = pd.DataFrame(dict_data)

# 타입 확인
print(type(df2))
# 데이터 확인
print(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        동물  나이
# 0     Dog   7
# 1     Cat   9
# 2   Tiger   2
# 3    Lion   3
# 4  Monkey   1

# %% [markdown]
# ### 데이터 요약 정보의 확인

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# ...

# %%
# 관련 라이브러리 불러오기
import pandas as pd     # 판다스
import seaborn as sns   # 시본
# 데이터 준비 시본에 내장된 팁 데이터
tips = sns.load_dataset('tips') # 팁 데이터
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
tips = pd.read_csv('tips.csv')
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %% [markdown]
# ## 상위 하위 데이터 추출

# %%
#데이터프레임에서 BM' 열의 상위 5개 데이터 추출
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#데이터프레임에서 BM' 열의 하위 3개 데이터 추출
tips.tail(3)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ## 인덱싱

# %%
tips1 = tips.drop([2])
tips1
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# 5             5       25.29  4.71    Male     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 8 columns]

# %%
tips1.iloc[2]
# Out:
# Unnamed: 0         3
# total_bill     23.68
# tip             3.31
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 3, dtype: object

# %%
tips1.loc[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python39\lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# g:\다른 컴퓨터\내 컴퓨터\korea_univ\2023fall\bigdata\Pandas\Pandas.ipynb Cell 26 line 1
# ...

# %%
tips1=tips1.drop([2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# g:\다른 컴퓨터\내 컴퓨터\korea_univ\2023fall\bigdata\Pandas\Pandas.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/%EB%8B%A4%EB%A5%B8%20%EC%BB%B4%ED%93%A8%ED%84%B0/%EB%82%B4%20%EC%BB%B4%ED%93%A8%ED%84%B0/korea_univ/2023fall/bigdata/Pandas/Pandas.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> tips1=tips1.drop([2])
#
# File c:\Python39\lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
# ...

# %%
# 특정조건 선택시 'isin' 함수 사용
# 일요일 이면 True
tips[tips['day'].isin(['Sun'])]
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0             0       16.99  1.01  Female     No  Sun  Dinner     2
# 1             1       10.34  1.66    Male     No  Sun  Dinner     3
# 2             2       21.01  3.50    Male     No  Sun  Dinner     3
# 3             3       23.68  3.31    Male     No  Sun  Dinner     2
# 4             4       24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...         ...   ...     ...    ...  ...     ...   ...
# 186         186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187         187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188         188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189         189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190         190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 8 columns]

# %%
# 팁을 1달러 지불한 고객
tips[tips['tip'].isin([1])]
# Out:
#      Unnamed: 0  total_bill  tip     sex smoker  day    time  size
# 67           67        3.07  1.0  Female    Yes  Sat  Dinner     1
# 92           92        5.75  1.0  Female    Yes  Fri  Dinner     2
# 111         111        7.25  1.0  Female     No  Sat  Dinner     1
# 236         236       12.60  1.0    Male    Yes  Sat  Dinner     2

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
print(s1)
print(s2)
# Out:
# a    0
# b    1
# dtype: int64
# c    2
# d    3
# e    4
# dtype: int64

# %%
df1 = pd.Dataframe([['Dog', 3], ['Cat', 2], ['Bird', 10]], columns=['동물', '나이'])
df2 = pd.DataFrame([['초원', '푸른색'], ['사막', '노란색'], ['숲', '초록색']], columns=['서식지', '색깔'])

# %% [markdown]
# ## 판다스의 활용

# %% [markdown]
# ### 데이터프레임의 생성

# %%
import pandas as pd
df = pd.read_csv('countries.csv')
df
# Out:
#   Unnamed: 0 country      area     capital  population
# 0         KR   Korea     98480       Seoul    51780579
# 1         US     USA   9629091  Washington   331002825
# 2         JP   Japan    377835       Tokyo   125960000
# 3         CN   China   9596960     Beijing  1439323688
# 4         RU  Russia  17100000      Moscow   146748600

# %% [markdown]
# ### Index 선택

# %%
import pandas as pd
df = pd.read_csv('countries.csv', index_col=0)
df
# Out:
#    country      area     capital  population
# KR   Korea     98480       Seoul    51780579
# US     USA   9629091  Washington   331002825
# JP   Japan    377835       Tokyo   125960000
# CN   China   9596960     Beijing  1439323688
# RU  Russia  17100000      Moscow   146748600

# %% [markdown]
# ### 열 기준의 데이터 추출

# %%
import pandas as pd
df_my_index = pd.read_csv('countries.csv', index_col=0)
df_no_index = pd.read_csv('countries.csv')
print(df_my_index['population'])
print(df_no_index['population'])
# Out:
# KR      51780579
# US     331002825
# JP     125960000
# CN    1439323688
# RU     146748600
# Name: population, dtype: int64
# 0      51780579
# 1     331002825
# 2     125960000
# 3    1439323688
# 4     146748600
# Name: population, dtype: int64

# %%
import pandas as pd

df_my_index = pd.read_csv('countries.csv', index_col=0)
print(df_my_index[ ['area', 'population'] ])
# Out:
#         area  population
# KR     98480    51780579
# US   9629091   331002825
# JP    377835   125960000
# CN   9596960  1439323688
# RU  17100000   146748600

# %% [markdown]
# ### 데이터 가시화

# %%
import pandas as pd
import matplotlib.pyplot as plt

countries_df = pd.read_csv('countries.csv', index_col=0)

countries_df['population'].plot(kind='bar', color=('b', 'darkorange', 'g', 'r', 'm'))
plt.show()

# %%
countries_df['population'].plot(kind='pie')
plt.show()

# %% [markdown]
# ### 인덱싱과 슬라이싱 예

# %%
countries_df[:3]
# Out:
#    country     area     capital  population
# KR   Korea    98480       Seoul    51780579
# US     USA  9629091  Washington   331002825
# JP   Japan   377835       Tokyo   125960000

# %%
countries_df.loc['KR']
# Out:
# country          Korea
# area             98480
# capital          Seoul
# population    51780579
# Name: KR, dtype: object

# %%
countries_df['population'][:3]
# Out:
# KR     51780579
# US    331002825
# JP    125960000
# Name: population, dtype: int64

# %%
countries_df.loc['US', 'capital']
# Out:
# 'Washington'

# %%
countries_df['capital'].loc['US']
# Out:
# 'Washington'

# %% [markdown]
# ### 새로운 열의 추가

# %%
import pandas as pd
import matplotlib.pyplot as plt

countries_df = pd.read_csv('countries.csv', index_col=0)
countries_df['density'] = countries_df['population'] / countries_df['area']
print(countries_df)
# Out:
#    country      area     capital  population     density
# KR   Korea     98480       Seoul    51780579  525.797918
# US     USA   9629091  Washington   331002825   34.375293
# JP   Japan    377835       Tokyo   125960000  333.373033
# CN   China   9596960     Beijing  1439323688  149.977044
# RU  Russia  17100000      Moscow   146748600    8.581789

# %% [markdown]
# ## CSV 모듈 vs. 판다스 모듈

# %% [markdown]
# ### CSV 모듈

# %%
import csv
f = open('weather.csv') # CSV 파일을 열어서 f에 저장한다.
data = csv.reader(f)    # reader() 함수를 이용하여 읽는다.
for row in data:
    print(row)
f.close()
# Out:
# ['일시', '평균기온(°C)', '최대 풍속(m/s)', '평균 풍속(m/s)']
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ...

# %%
import csv

f = open('weather.csv') # CSV 파일을 열어서 f에 저장한다.
data = csv.reader(f)    # csv의 reader() 함수를 이용하여 읽는다.
header = next(data)     # 헤더를 제거한다.
for row in data:        # 반복 루프를 사용하여 데이터를 읽는다.
    print(row)
f.close()               # 파일을 닫는다.
# Out:
# ['2010-08-01', '28.7', '8.3', '3.4']
# ['2010-08-02', '25.2', '8.7', '3.8']
# ['2010-08-03', '22.1', '6.3', '2.9']
# ['2010-08-04', '25.3', '6.6', '4.2']
# ['2010-08-05', '27.2', '9.1', '5.6']
# ['2010-08-06', '26.8', '9.8', '8']
# ['2010-08-07', '27.5', '9.1', '5']
# ['2010-08-08', '26.6', '5.9', '4']
# ['2010-08-09', '26.9', '5.1', '3.1']
# ['2010-08-10', '25.6', '10.2', '5.5']
# ['2010-08-11', '24.6', '9.4', '4.8']
# ['2010-08-12', '23.7', '8.7', '2.6']
# ['2010-08-13', '24.3', '10.9', '4.6']
# ['2010-08-14', '25', '10.8', '4.4']
# ['2010-08-15', '24.5', '16.9', '10.3']
# ['2010-08-16', '26.2', '9.8', '3.2']
# ['2010-08-17', '23.9', '4.2', '1.6']
# ['2010-08-18', '23.4', '4.2', '2.1']
# ['2010-08-19', '24.3', '4', '1.9']
# ['2010-08-20', '25.4', '5', '3.2']
# ['2010-08-21', '27.8', '7.6', '4.2']
# ['2010-08-22', '28.3', '5.9', '2.5']
# ['2010-08-23', '28.9', '9.3', '6.2']
# ['2010-08-24', '27.5', '8.3', '3']
# ['2010-08-25', '24.7', '6.8', '1.9']
# ...

# %% [markdown]
# ### 원하는 데이터의 추출

# %%
import csv

f = open('weather.csv')     # CSV 파일을 열어서 f에 저장한다.
data = csv.reader(f)        # reader() 함수를 이용하여 읽는다.
header = next(data)         # 헤더를 제거한다.
for row in data:            # 반복 루프를 사용하여 데이터를 읽는다.
    print(row[3], end=',')  # 평균풍속만 출력하고, 쉼표로 연결한다.
f.close()                   # 파일을 닫는다.
# Out:
# 3.4,3.8,2.9,4.2,5.6,8,5,4,3.1,5.5,4.8,2.6,4.6,4.4,10.3,3.2,1.6,2.1,1.9,3.2,4.2,2.5,6.2,3,1.9,2.5,1.6,2.3,4.9,6.2,4.2,2.6,5.3,1.7,3.2,3.3,4.3,7.6,6.6,2.5,7.2,3.8,1.8,3.9,1.6,2.2,1.2,2.2,3,3.5,2.8,3.6,7.9,5.8,4.1,6.1,1.8,2.8,5.6,2.1,2.2,3.3,3.2,5.9,5,5.1,3.1,3.4,3.7,2.7,2.6,3.1,2.5,5,3.2,2.9,4.5,2.9,2.9,2.1,3.9,6.3,3.9,2,3,6.1,7.1,4,3.5,5.8,6.6,7.2,5.6,3.5,3.2,2.9,3.2,3.3,2.5,7.5,3.1,2.2,2.8,6.7,3.5,5,4.1,1.9,3.9,2.7,5.1,2.2,4.3,8.8,5.2,1.8,3.9,3.9,6.5,4.2,3.7,5.8,5.1,4.2,5.7,3.7,5.4,5.6,6.4,3.4,5.9,5.4,5.4,1.8,3.6,5.1,2.4,2.1,4.3,2.3,7.6,2.9,2,5.2,3.3,3.7,5.3,6.1,4,4.6,2.5,4.3,7.8,11.1,6,6.5,3.1,4.1,5.9,2.4,3.3,5.4,2.6,2.4,3.2,2.3,3.1,5.6,5.6,3.6,3,2.9,2.5,2,2,3.2,4.6,4,3.8,2.8,1.7,3.2,1.9,3.3,2,2.5,2.4,3.5,2.4,4.6,3.5,4.2,5.2,5,5.7,9.7,4.2,7,4.5,4.3,4.4,5.6,5.4,6.3,4.8,2,4.1,6.2,5.9,2.4,5.3,7.4,3.2,4.9,2.8,2.5,5.2,2.9,3.6,2.9,4.2,4,2.9,5.5,4.4,7.1,3.8,4.8,4.1,6.6,6.2,3.8,3.4,5.8,2.9,3.2,5.3,2.7,3.7,2.1,2.7,3.9,3.4,5,5.9,3.3,3,4.2,6.1,8.3,5.4,5.9,7.4,3.3,7,5.3,4,8.8,7,1.9,7,12.1,5,2.5
# ...

# %% [markdown]
# ### 원하는 데이터의 조회

# %%
import csv

f = open('weather.csv')         # CSV 파일을 열어서 f에 저장한다.
data = csv.reader(f)            # reader() 함수를 이용하여 읽는다.
header = next(data)             # 헤더를 제거한다.

max_wind = 0.0

for row in data:                # 반복 루프를 사용하여 데이터를 읽는다.
    if row[3] == '':            # 평균 풍속 데이터가 없는 경우 0을 처리
        wind = 0
    else:
        wind = float(row[3])    # 평균 풍속 데이터를 실수로 변환해 저장
    if max_wind < wind:         # 최대 풍속을 갱신하는지 검사
        max_wind = wind         # 현재까지의 최대 풍속보다 크면 새로 기록
        
print('지난 10년간 울릉도의 최대 풍속은 ', max_wind, 'm/s')
# Out:
# 지난 10년간 울릉도의 최대 풍속은  14.9 m/s

# %% [markdown]
# ### Lab 9-1

# %%
import csv
import matplotlib.pyplot as plt

f = open('weather.csv')                 # CSV 파일을 열어서 f에 저장
data = csv.reader(f)                    # reader() 함수로 읽기
header = next(data)                     # 헤더를 제거

monthly_wind = [0 for x in range(12)]   # 매달 풍속을 담을 리스트, 초기화 0
days_counted = [0 for x in range(12)]   # 각 달마다 측정된 일수, 초기화 0

for row in data:
    month = int(row[0][5:7])            # 0번 열에서 달 정보 추출
    if row[3] != '':                    # 풍속 데이터 존재하는지 확인
        wind = float(row[3])            # 풍속을 얻어 온다
        monthly_wind[month-1] += wind   # 해당 달에 풍속 데이터 추가
        days_counted[month-1] += 1      # 해당 달의 일수를 증가

for i in range(12):
    monthly_wind[i] /= days_counted[i]  # 일수로 나누어 월평균 구하기
    
plt.plot(monthly_wind, 'blue')
plt.show()

f.close()                               # 파일을 닫는다.

# %% [markdown]
# ### 데이터의 분석

# %%
import pandas as pd
weather = pd.read_csv('weather.csv', index_col=0, encoding='cp949')

print(weather.describe())
# Out:
#           평균기온(°C)   최대 풍속(m/s)   평균 풍속(m/s)
# count  3653.000000  3649.000000  3647.000000
# mean     12.942102     7.911099     3.936441
# std       8.538507     3.029862     1.888473
# min      -9.000000     2.000000     0.200000
# 25%       5.400000     5.700000     2.500000
# 50%      13.800000     7.600000     3.600000
# 75%      20.100000     9.700000     5.000000
# max      31.300000    26.000000    14.900000

# %%
weather.count()
# Out:
# 평균기온(°C)      3653
# 최대 풍속(m/s)    3649
# 평균 풍속(m/s)    3647
# dtype: int64

# %%
weather['최대 풍속(m/s)'].count()
# Out:
# 3649

# %%
weather[['최대 풍속(m/s)', '평균 풍속(m/s)']].mean()
# Out:
# 최대 풍속(m/s)    7.911099
# 평균 풍속(m/s)    3.936441
# dtype: float64

# %% [markdown]
# ### Lab 9-2 : csv 모듈 vs. 판다스 모듈

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

weather = pd.read_csv('weather.csv', encoding='cp949')
monthly = [None for x in range(12)]     # 달별로 구분된 12개의 데이터프레임
monthly_wind = [0 for x in range(12)]   # 각 달의 평균 풍속을 담을 리스트
# 마지막에 해당 행의 데이터가 측정된 달을 기록한 열을 추가
weather['month'] = pd.DatetimeIndex(weather['일시']).month

for i in range(12):
    monthly[i] = weather[ weather['month'] == i + 1 ]   # 달별로 분리
    monthly_wind[i] = monthly[i]['평균 풍속(m/s)'].mean()   # 개별 데이터 분석
    
plt.plot(monthly_wind, 'red')
plt.show()

# %% [markdown]
# ### (추가)

# %%
weather['month']=pd.DatetimeIndex(weather['일시']).month
# weather['month'] : weather 데이터프레임에 'month' 열 추가
# pd.DatetimeIndex(weather['일시']).month : weather['일시'] 열 로부터 month 추출
# 일시는  xxxx-xx-xx 형태로 되어 있어야 한다.
# datetime 모듈 import 가 필요하다

# %% [markdown]
# ### 데이터 그룹핑

# %%
import pandas as pd
df = pd.DataFrame({'마트':[1, 1, 1, 2, 2, 3, 3], 
                    '무게':[150, 200, 160, 200, 170, 220, 160],
                    '등급':[1,3,2,1,2,1,1]})

df
# Out:
#    마트   무게  등급
# 0   1  150   1
# 1   1  200   3
# 2   1  160   2
# 3   2  200   1
# 4   2  170   2
# 5   3  220   1
# 6   3  160   1

# %%
test1 = df.groupby('마트')['무게'].mean()
test1
# Out:
# 마트
# 1    170.0
# 2    185.0
# 3    190.0
# Name: 무게, dtype: float64
